# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('dark_background')

# %% [markdown]
# ### Import Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/algonacci/Data-Warehouse/main/boston_housing.csv')
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
print(f'Total Data : {df.shape[0]}')
print(f'Total Column : {df.shape[1]}')
# Out:
# Total Data : 506
# Total Column : 14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.nunique()
# Out:
# crim       504
# zn          26
# indus       76
# chas         2
# nox         81
# rm         446
# age        356
# dis        412
# rad          9
# tax         66
# ptratio     46
# b          357
# lstat      455
# medv       229
# dtype: int64

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# crim     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# zn       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# indus    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# chas     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# nox      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# rm       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# age      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# dis      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# rad      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# tax      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# ptratio  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# b        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# lstat    506.0   12.653063    7.141062    1.73000    6.950000   11.36000
# medv     506.0   22.532806    9.197104    5.00000   17.025000   21.20000
#
#                 75%       max
# crim       3.677083   88.9762
# zn        12.500000  100.0000
# indus     18.100000   27.7400
# chas       0.000000    1.0000
# nox        0.624000    0.8710
# rm         6.623500    8.7800
# age       94.075000  100.0000
# dis        5.188425   12.1265
# rad       24.000000   24.0000
# tax      666.000000  711.0000
# ptratio   20.200000   22.0000
# b        396.225000  396.9000
# lstat     16.955000   37.9700
# medv      25.000000   50.0000

# %% [markdown]
# ### Data Visualization

# %%
columns = df.columns
for col in columns:
    plt.figure(figsize=(15,8))
    sns.scatterplot(data=df[col])
    plt.title(col.upper(), fontsize=20, pad=20)
    plt.show()

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ### Handling Outliers

# %%
columns = df.columns

for column in columns:
    sns.boxplot(x=df[column])
    plt.title(column.upper(), fontsize=20, pad=10)
    plt.show()

# %%
# function Check Outliers
def data_outlier(df):
  for k, v in df.items():
    Q1        = v.quantile(0.25)
    Q3        = v.quantile(0.75)
    IQR       = Q3 - Q1
    v_range   = v[(v <= Q1 - 1.5 * IQR) | (v >= Q3 + 1.5 * IQR)]
    perc      = np.shape(v_range)[0] * 100.0 / df.shape[0]
    col_mean  = v.mean()
    col_medn  = v.median()     
    print(f'Column {k}, outliers = {perc:.2f} % , mean = {col_mean:.2f}, median = {col_medn:.2f}')

# %% [markdown]
# ### Check Correlation

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), annot=True,linewidths=.5,cmap="Blues")
plt.show()

# %%
drop_col = ['crim','indus','nox','age','rad','tax','ptratio','lstat']
df_clear = df.drop(drop_col, axis=1)

# %%
df_clear
# Out:
#        zn  chas     rm     dis       b  medv
# 0    18.0     0  6.575  4.0900  396.90  24.0
# 1     0.0     0  6.421  4.9671  396.90  21.6
# 2     0.0     0  7.185  4.9671  392.83  34.7
# 3     0.0     0  6.998  6.0622  394.63  33.4
# 4     0.0     0  7.147  6.0622  396.90  36.2
# ..    ...   ...    ...     ...     ...   ...
# 501   0.0     0  6.593  2.4786  391.99  22.4
# 502   0.0     0  6.120  2.2875  396.90  20.6
# 503   0.0     0  6.976  2.1675  396.90  23.9
# 504   0.0     0  6.794  2.3889  393.45  22.0
# 505   0.0     0  6.030  2.5050  396.90  11.9
#
# [506 rows x 6 columns]

# %% [markdown]
# ### Splitting the data

# %%
from sklearn.model_selection import train_test_split

# with drop - correlation
X = df_clear.drop('medv', axis=1)
y = df_clear['medv']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=.2)

# without drop
X2 = df.drop('medv', axis=1)
y2 = df['medv']

X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, random_state=42, test_size=.2)

# %% [markdown]
# ### Standarization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

scaler.fit(X2_train)
X2_train = scaler.transform(X2_train)
X2_test = scaler.transform(X2_test)

# %% [markdown]
# ### Modelling

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr2 = LinearRegression()
lr2.fit(X2_train, y2_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Testing the model

# %%
from sklearn.metrics import r2_score

accuracy_score = lr.score(X_train, y_train)
print(f'Accuracy Score data train 1: {accuracy_score * 100:.2f}')
accuracy_score = lr.score(X_test, y_test) 
print(f'Accuracy Score data test 1: {accuracy_score * 100:.2f}')


accuracy_score2 = lr2.score(X2_train, y2_train) 
print(f'Accuracy Score data train 2: {accuracy_score2 * 100:.2f}')

accuracy_score2 = lr2.score(X2_test, y2_test) 
print(f'Accuracy Score data test 2: {accuracy_score2 * 100:.2f}')
# Out:
# Accuracy Score data train 1: 59.24
# Accuracy Score data test 1: 45.23
# Accuracy Score data train 2: 75.09
# Accuracy Score data test 2: 66.88

# %%
medv_predict = lr.predict(X_test)
medv_predict
# Out:
# array([23.98686738, 32.51549725, 20.27336241, 20.55956276, 22.7463413 ,
#        22.08995735, 19.4351163 , 21.87423481, 22.33899941, 20.74085194,
#        24.01287772, 20.33481298,  0.16997022, 21.89561222, 17.60748217,
#        28.25454519, 19.09958107, 10.51119086, 39.56595208, 22.11112251,
#        23.2078267 , 26.19993491, 16.92058391, 25.42003313, 18.67661593,
#        14.52697238, 19.16925972, 16.7226823 , 23.87180826, 18.71440381,
#        16.86818465, 23.86929372, 31.80027979, 14.73697292, 18.85630427,
#        14.70634751, 30.15127845, 19.05668672, 24.40396035, 21.73582755,
#        15.29857872, 29.118174  , 41.56461989, 17.1283271 , 23.85447955,
#        18.08558728, 16.839074  , 23.36266484, 21.86135591, 26.00243423,
#        20.68342635, 29.16256015, 21.53060896, 27.0592993 , 33.67074117,
#        22.75961407, 22.40097729, 31.09791876, 23.52532178, 17.26875544,
#        27.38194131, 34.36620621, 24.66191499, 12.97712152, 26.43229401,
#        18.7389612 , 24.47936564, 23.83731923, 28.54724698, 10.42891177,
#        18.36892447, 26.67237861, 15.35501223, 22.02949774, 21.24549563,
#        15.99768852, 21.83084124, 40.08591395, 25.25882318, 14.28362833,
#        19.59725869, 15.29264311, 22.18095185, 12.4244764 , 20.64936636,
#        29.55502793, 22.82863795, 23.75324448, 23.40422184, 24.37316014,
#        20.45485912,  7.82982149, 23.30622696, 18.12818629, -1.14790753,
#        23.40490553, 21.72617898, -0.41120086, 15.05090051, 16.96664124,
#        20.37323951, 22.33712307])

# %%
medv_predict2 = lr2.predict(X2_test)
medv_predict2
# Out:
# array([28.99672362, 36.02556534, 14.81694405, 25.03197915, 18.76987992,
#        23.25442929, 17.66253818, 14.34119   , 23.01320703, 20.63245597,
#        24.90850512, 18.63883645, -6.08842184, 21.75834668, 19.23922576,
#        26.19319733, 20.64773313,  5.79472718, 40.50033966, 17.61289074,
#        27.24909479, 30.06625441, 11.34179277, 24.16077616, 17.86058499,
#        15.83609765, 22.78148106, 14.57704449, 22.43626052, 19.19631835,
#        22.43383455, 25.21979081, 25.93909562, 17.70162434, 16.76911711,
#        16.95125411, 31.23340153, 20.13246729, 23.76579011, 24.6322925 ,
#        13.94204955, 32.25576301, 42.67251161, 17.32745046, 27.27618614,
#        16.99310991, 14.07009109, 25.90341861, 20.29485982, 29.95339638,
#        21.28860173, 34.34451856, 16.04739105, 26.22562412, 39.53939798,
#        22.57950697, 18.84531367, 32.72531661, 25.0673037 , 12.88628956,
#        22.68221908, 30.48287757, 31.52626806, 15.90148607, 20.22094826,
#        16.71089812, 20.52384893, 25.96356264, 30.61607978, 11.59783023,
#        20.51232627, 27.48111878, 11.01962332, 15.68096344, 23.79316251,
#         6.19929359, 21.6039073 , 41.41377225, 18.76548695,  8.87931901,
#        20.83076916, 13.25620627, 20.73963699,  9.36482222, 23.22444271,
#        31.9155003 , 19.10228271, 25.51579303, 29.04256769, 20.14358566,
#        25.5859787 ,  5.70159447, 20.09474756, 14.95069156, 12.50395648,
#        20.72635294, 24.73957161, -0.164237  , 13.68486682, 16.18359697,
#        22.27621999, 24.47902364])

# %% [markdown]
# ### Evaluation

# %% [markdown]
# #### Mean Absolute Error

# %%
from sklearn.metrics import mean_absolute_error

print(f'MAE model 1 :{mean_absolute_error(y_test,medv_predict)}')
print(f'MAE model 2 :{mean_absolute_error(y2_test,medv_predict2)}')
# Out:
# MAE model 1 :3.959928558642937
# MAE model 2 :3.1890919658878474

# %% [markdown]
# #### Mean Squared Error

# %%
from sklearn.metrics import mean_squared_error
print(f'MSE model 1 :{mean_squared_error(y_test, medv_predict)}')
print(f'MSE model 2 :{mean_squared_error(y2_test, medv_predict2)}')
# Out:
# MSE model 1 :40.168143047571206
# MSE model 2 :24.29111947497351

# %% [markdown]
# #### Root Mean Squared Error

# %%
print(f'RMSE model 1 :{np.sqrt(mean_squared_error(y_test, medv_predict))}')
print(f'RMSE model 2 :{np.sqrt(mean_squared_error(y2_test, medv_predict2))}')
# Out:
# RMSE model 1 :6.33783425529346
# RMSE model 2 :4.928602182665336
