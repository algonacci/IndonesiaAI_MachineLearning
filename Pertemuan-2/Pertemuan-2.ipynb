# %% [markdown]
# ### Import Libraries

# %%
from sklearn.datasets import load_iris

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import klib

plt.style.use('dark_background')

# %%
from jupyterthemes import jtplot

jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)

# %%
plt.rcParams.update({
    "lines.color": "white",
    "patch.edgecolor": "white",
    "text.color": "white",
    "axes.facecolor": "black",
    "axes.edgecolor": "white",
    "axes.labelcolor": "white",
    "xtick.color": "white",
    "ytick.color": "white",
    "grid.color": "white",
    "figure.facecolor": "black",
    "figure.edgecolor": "black",
    "savefig.facecolor": "black",
    "savefig.edgecolor": "black"})

# %% [markdown]
# ### Data Loading

# %%
df = pd.read_csv('https://raw.githubusercontent.com/algonacci/Data-Warehouse/main/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
print(f'Jumlah data : {df.shape[0]}')
print(f'Jumlah kolom : {df.shape[1]}')
# Out:
# Jumlah data : 150
# Jumlah kolom : 5

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Histogram for Distribution

# %%
df['sepal_length'].hist() 
plt.xlabel('Sepal Length')
plt.ylabel('Density')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(5,5))
df['petal_length'].hist() 
plt.xlabel('Petal Length')
plt.ylabel('Density')
plt.grid(visible=None)
plt.show()

# %% [markdown]
# #### Using Klib

# %%
klib.dist_plot(df)
plt.show()

# %%
df['species'].hist()
plt.grid()
plt.show()

# %% [markdown]
# #### Using Seaborn

# %%
sns.countplot(x=df['species'])
plt.show()

# %% [markdown]
# ### Scatter plot - Distribution & Relation

# %%
df.plot(kind='scatter',x='sepal_length',y='sepal_width', c='lightblue')
plt.show()

# %%
sns.scatterplot(data=df, x='sepal_length',y='sepal_width', hue='species')
plt.show()

# %%
df.plot(kind='scatter',x='petal_length',y='petal_width', c='lightblue')
plt.show()

# %%
sns.scatterplot(data= df, x='petal_length',y='petal_width', hue='species', palette='bright')
plt.show()

# %% [markdown]
# ### Displot - Distribution

# %%
sns.displot(df['sepal_length'],kde=True)
plt.show()

# %%
sns.kdeplot(x=df['sepal_length'], hue=df['species'], shade=True, palette='bright')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.displot(x=df['sepal_length'], kde=True, bins=20)
plt.show()

# %% [markdown]
# ### Boxplot - Distribution and Comparison

# %%
sns.boxplot(data=df)
plt.xlabel('Features')
plt.ylabel('Length (cm)')
plt.show()

# %%
sns.boxplot(data=df, y='petal_length',x='species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.show()

# %% [markdown]
# ### Pairplot - Relation, Distribution, Comparison

# %%
sns.pairplot(data=df)
plt.show()

# %%
sns.pairplot(data=df, hue='species')
plt.show()

# %% [markdown]
# ### Heatmap - Correlation

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(data=df.corr())
plt.show()

# %% [markdown]
# #### With `annot=True`

# %%
sns.heatmap(data=df.corr(), annot=True)
plt.show()

# %% [markdown]
# #### Keterangan :
# ![image](https://user-images.githubusercontent.com/76864673/139577422-73a2454f-5cac-4759-a6b6-7bc1125764f8.png)
